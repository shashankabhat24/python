# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as  pd

# %%
x=[1.5,2.6,3.6]
y=[4.6,8.6,4.2]
z=[47,58,62]*5
plt.title('every end is the new begining',fontdict={'fontname' : 'Consolas','fontsize' : 20})
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y,z)
plt.show()
# Out:
# findfont: Font family ['Consolas'] not found. Falling back to DejaVu Sans.
