# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/home/shashu/python and data science/pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.head(6)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
df.tail(2)
# Out:
#        #                Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 798  720  HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721           Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.tail(45)
# Out:
#        #                   Name    Type 1   Type 2   HP  Attack  Defense  \
# 755  685               Slurpuff     Fairy      NaN   82      80       86
# 756  686                  Inkay      Dark  Psychic   53      54       53
# 757  687                Malamar      Dark  Psychic   86      92       88
# 758  688                Binacle      Rock    Water   42      52       67
# 759  689             Barbaracle      Rock    Water   72     105      115
# 760  690                 Skrelp    Poison    Water   50      60       60
# 761  691               Dragalge    Poison   Dragon   65      75       90
# 762  692              Clauncher     Water      NaN   50      53       62
# 763  693              Clawitzer     Water      NaN   71      73       88
# 764  694             Helioptile  Electric   Normal   44      38       33
# 765  695              Heliolisk  Electric   Normal   62      55       52
# 766  696                 Tyrunt      Rock   Dragon   58      89       77
# ...

# %%
df.tail(4
       )
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df['Defense'][0:10])
# Out:
# 0     49
# 1     63
# 2     83
# 3    123
# 4     43
# 5     58
# 6     78
# 7    111
# 8     78
# 9     65
# Name: Defense, dtype: int64

# %%
print(df.values)
# Out:
# [[1 'Bulbasaur' 'Grass' ... 45 1 False]
#  [2 'Ivysaur' 'Grass' ... 60 1 False]
#  [3 'Venusaur' 'Grass' ... 80 1 False]
#  ...
#  [720 'HoopaHoopa Confined' 'Psychic' ... 70 6 True]
#  [720 'HoopaHoopa Unbound' 'Psychic' ... 80 6 True]
#  [721 'Volcanion' 'Fire' ... 70 6 True]]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df[['Name','Attack','Speed','Generation'][0:4]]
# Out:
#                       Name  Attack  Speed  Generation
# 0                Bulbasaur      49     45           1
# 1                  Ivysaur      62     60           1
# 2                 Venusaur      82     80           1
# 3    VenusaurMega Venusaur     100     80           1
# 4               Charmander      52     65           1
# ..                     ...     ...    ...         ...
# 795                Diancie     100     50           6
# 796    DiancieMega Diancie     160    110           6
# 797    HoopaHoopa Confined     110     70           6
# 798     HoopaHoopa Unbound     160     80           6
# 799              Volcanion     110     70           6
#
# [800 rows x 4 columns]

# %%
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.iloc[14]
# Out:
# #                  11
# Name          Metapod
# Type 1            Bug
# Type 2            NaN
# HP                 50
# Attack             20
# Defense            55
# Sp. Atk            25
# Sp. Def            25
# Speed              30
# Generation          1
# Legendary       False
# Name: 14, dtype: object

# %%
df.iloc[10
       ]
# Out:
# #                     8
# Name          Wartortle
# Type 1            Water
# Type 2              NaN
# HP                   59
# Attack               63
# Defense              80
# Sp. Atk              65
# Sp. Def              80
# Speed                58
# Generation            1
# Legendary         False
# Name: 10, dtype: object

# %%
df.iloc[0:6]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
df.iloc[0:2]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
df.iloc[1,2]
# Out:
# 'Grass'

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[798,8]
# Out:
# 130

# %%
df.iloc[4,2]
# Out:
# 'Fire'

# %%
for index,rows in df.iterrows():
    print(index,rows,['Type 1 '])
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object ['Type 1 ']
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object ['Type 1 ']
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# ...

# %%
df.loc[df['Type 2'] == "Fire"]
# Out:
#        #                   Name    Type 1 Type 2   HP  Attack  Defense  \
# 246  228               Houndour      Dark   Fire   45      60       30
# 247  229               Houndoom      Dark   Fire   75      90       50
# 248  229  HoundoomMega Houndoom      Dark   Fire   75      90       90
# 424  383  GroudonPrimal Groudon    Ground   Fire  100     180      160
# 532  479        RotomHeat Rotom  Electric   Fire   50      65      107
# 553  494                Victini   Psychic   Fire  100     100      100
# 668  607                Litwick     Ghost   Fire   50      30       55
# 669  608                Lampent     Ghost   Fire   60      40       60
# 670  609             Chandelure     Ghost   Fire   60      55       90
# 697  636               Larvesta       Bug   Fire   55      85       55
# 698  637              Volcarona       Bug   Fire   85      60       65
# 706  643               Reshiram    Dragon   Fire  100     120      100
#
# ...

# %%
df.loc[df['Type 2']== "Poison"]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Attack']==100]
# Out:
#        #                   Name    Type 1   Type 2   HP  Attack  Defense  \
# 3      3  VenusaurMega Venusaur     Grass   Poison   80     100      123
# 33    28              Sandslash    Ground      NaN   75     100      110
# 73    67                Machoke  Fighting      NaN   80     100       70
# 84    78               Rapidash      Fire      NaN   65     100       70
# 138  128                 Tauros    Normal      NaN   75     100       95
# 158  146                Moltres      Fire   Flying   90     100       90
# 165  151                    Mew   Psychic      NaN  100     100      100
# 200  185              Sudowoodo      Rock      NaN   70     100      115
# 239  221              Piloswine       Ice   Ground  100     100       80
# 271  251                 Celebi   Psychic    Grass  100     100      100
# 298  275                Shiftry     Grass     Dark   90     100       60
# 336  308  MedichamMega Medicham  Fighting  Psychic   60     100       85
# ...

# %%
df.loc[df['Legendary']==False]
# Out:
#        #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur   Grass  Poison  45      49       49       65
# 1      2                Ivysaur   Grass  Poison  60      62       63       80
# 2      3               Venusaur   Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4      4             Charmander    Fire     NaN  39      52       43       60
# ..   ...                    ...     ...     ...  ..     ...      ...      ...
# 787  711    GourgeistSuper Size   Ghost   Grass  85     100      122       58
# 788  712               Bergmite     Ice     NaN  55      69       85       32
# 789  713                Avalugg     Ice     NaN  95     117      184       44
# 790  714                 Noibat  Flying  Dragon  40      30       35       45
# 791  715                Noivern  Flying  Dragon  85      70       80       97
#
# ...

# %%
df.loc[df['Type 1']=="Ghost"]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 99    92                 Gastly  Ghost  Poison   30      35       30      100
# 100   93                Haunter  Ghost  Poison   45      50       45      115
# 101   94                 Gengar  Ghost  Poison   60      65       60      130
# 102   94      GengarMega Gengar  Ghost  Poison   60      65       80      170
# 215  200             Misdreavus  Ghost     NaN   60      60       60       85
# 385  353                Shuppet  Ghost     NaN   44      75       35       63
# 386  354                Banette  Ghost     NaN   64     115       65       83
# 387  354    BanetteMega Banette  Ghost     NaN   64     165       75       93
# 388  355                Duskull  Ghost     NaN   20      40       90       30
# 389  356               Dusclops  Ghost     NaN   40      70      130       60
# 472  425               Drifloon  Ghost  Flying   90      50       34       60
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Attack')
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  440                  Happiny   Normal       NaN  100       5        5
# 121  113                  Chansey   Normal       NaN  250       5        5
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# ..   ...                      ...      ...       ...  ...     ...      ...
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name',ascending=True)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name',ascending=True)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Attack',ascending=True)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  440                  Happiny   Normal       NaN  100       5        5
# 121  113                  Chansey   Normal       NaN  250       5        5
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# ..   ...                      ...      ...       ...  ...     ...      ...
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Defense')
# Out:
#        #                 Name    Type 1  Type 2   HP  Attack  Defense  \
# 121  113              Chansey    Normal     NaN  250       5        5
# 488  440              Happiny    Normal     NaN  100       5        5
# 261  242              Blissey    Normal     NaN  255      10       10
# 186  172                Pichu  Electric     NaN   20      40       15
# 188  174            Igglybuff    Normal   Fairy   90      30       15
# ..   ...                  ...       ...     ...  ...     ...      ...
# 414  377             Regirock      Rock     NaN   80     100      200
# 223  208              Steelix     Steel  Ground   75      85      200
# 333  306    AggronMega Aggron     Steel     NaN   70     140      230
# 230  213              Shuckle       Bug    Rock   20      10      230
# 224  208  SteelixMega Steelix     Steel  Ground   75     125      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 121       35      105     50           1      False
# ...

# %%
df.sort_values(['Name','Attack'])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.sort_values(['Name','HP'],ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Speed']
df['total']
# Out:
# 0      253
# 1      325
# 2      425
# 3      505
# 4      259
#       ...
# 795    450
# 796    590
# 797    470
# 798    550
# 799    510
# Name: total, Length: 800, dtype: int64

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  total
# 0       65     45           1      False    253
# 1       80     60           1      False    325
# 2      100     80           1      False    425
# 3      120     80           1      False    505
# 4       50     65           1      False    259

# %%
df.pop('total')
# Out:
# 0      253
# 1      325
# 2      425
# 3      505
# 4      259
#       ...
# 795    450
# 796    590
# 797    470
# 798    550
# 799    510
# Name: total, Length: 800, dtype: int64

# %%
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df=df.drop(columns=['Generation'])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# 0         65       65     45      False
# 1         80       80     60      False
# ...

# %%
df['total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df['total']
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: total, Length: 800, dtype: int64

# %%
df['total']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    NaN
# ...

# %%
df['total']=df.iloc[:,4:6].sum(axis=0)

# %%
df['total']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 795   NaN
# 796   NaN
# 797   NaN
# 798   NaN
# 799   NaN
# Name: total, Length: 800, dtype: float64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    NaN
# ...

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Legendary  total
# 0       65     45      False    NaN
# 1       80     60      False    NaN
# 2      100     80      False    NaN
# 3      120     80      False    NaN
# 4       50     65      False    NaN

# %%
df['total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df['total']
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: total, Length: 800, dtype: int64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.to_csv('modified.csv',index=False)

# %%
sd=pd.read_csv('modified.csv')

# %%
sd
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.loc[df['Type 1']=="Grass"[0:5]]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df['HP']==50)| (df['Legendary']==False)]
# Out:
#        #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur   Grass  Poison  45      49       49       65
# 1      2                Ivysaur   Grass  Poison  60      62       63       80
# 2      3               Venusaur   Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4      4             Charmander    Fire     NaN  39      52       43       60
# ..   ...                    ...     ...     ...  ..     ...      ...      ...
# 789  713                Avalugg     Ice     NaN  95     117      184       44
# 790  714                 Noibat  Flying  Dragon  40      30       35       45
# 791  715                Noivern  Flying  Dragon  85      70       80       97
# 795  719                Diancie    Rock   Fairy  50     100      150      100
# 796  719    DiancieMega Diancie    Rock   Fairy  50     160      110      160
#
# ...

# %%
new_df=df.loc[(df['Type 1']=='Rock') & (df['Type 2']=='Dark')]

# %%
new_df
# Out:
#        #                     Name Type 1 Type 2   HP  Attack  Defense  \
# 267  248                Tyranitar   Rock   Dark  100     134      110
# 268  248  TyranitarMega Tyranitar   Rock   Dark  100     164      150
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 267       95      100     61      False    600
# 268       95      120     71      False    700

# %%
new_df.to_csv('new_df.csv')

# %%
xz=pd.read_csv('new_df.csv')

# %%
xz
# Out:
#    Unnamed: 0    #                     Name Type 1 Type 2   HP  Attack  \
# 0         267  248                Tyranitar   Rock   Dark  100     134
# 1         268  248  TyranitarMega Tyranitar   Rock   Dark  100     164
#
#    Defense  Sp. Atk  Sp. Def  Speed  Legendary  total
# 0      110       95      100     61      False    600
# 1      150       95      120     71      False    700

# %%
sd
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
sd=sd.head(6)

# %%
sd
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Legendary  total
# 0       65     45      False    318
# 1       80     60      False    405
# 2      100     80      False    525
# 3      120     80      False    625
# 4       50     65      False    309
# 5       65     80      False    405

# %%
sd=sd.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5193/2913156007.py in <module>
# ----> 1 sd=sd.reset_index(drop=True)
#
# AttributeError: 'function' object has no attribute 'reset_index'

# %%
sd.head(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5193/685475656.py in <module>
# ----> 1 sd.head(1)
#
# AttributeError: 'function' object has no attribute 'head'

# %%
sd
# Out:
# <bound method DataFrame.reset_index of    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Legendary  total
# 0       65     45      False    318
# 1       80     60      False    405
# 2      100     80      False    525
# 3      120     80      False    625
# 4       50     65      False    309
# 5       65     80      False    405  >

# %%
m=df.loc[df['Name'].str.contains('Venusaur')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5193/662049036.py in <module>
# ----> 1 m=df.loc[df['Name'].str.contains('Venusaur')]
#
# AttributeError: 'str' object has no attribute 'loc'

# %%
m
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Legendary  total
# 2      100     80      False    525
# 3      120     80      False    625

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
m
# Out:
#    # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary  \
# 2  3  Grass  Poison  80      82       83      100      100     80      False
# 3  3  Grass  Poison  80     100      123      122      120     80      False
#
#    total
# 2    525
# 3    625

# %%
import re

df.loc[df['Name'].str.contains('Mega',regex=True)]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
import re 
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
import re
n=df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]

# %%
n1=n.head(6)

# %%
n1
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Legendary  total
# 0       65     45      False    318
# 1       80     60      False    405
# 2      100     80      False    525
# 3      120     80      False    625
# 4       50     65      False    309
# 5       65     80      False    405

# %%
import re
l=df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]

# %%
l.head(10)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
#
#     Sp. Atk  Sp. Def  Speed  Legendary  total
# 0        65       65     45      False    318
# 1        80       80     60      False    405
# 2       100      100     80      False    525
# ...

# %%
df.pop('total')
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: total, Length: 800, dtype: int64

# %%
import pandas as pd

# %%
import re
x=df.loc[df['Name'].str.contains('^ka[a-z]*',flags=re.I,regex=True)]
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5193/1728382907.py in <module>
#       1 import re
# ----> 2 x=df.loc[df['Name'].str.contains('^ka[a-z]*',flags=re.I,regex=True)]
#       3 x
#
# AttributeError: 'str' object has no attribute 'loc'

# %%
df.loc[df['Type 1']=='Rock','Type 1']=='Stone'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass    king  80      82       83
# 3      3  VenusaurMega Venusaur    Grass    king  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock    king  50     100      150
# 796  719    DiancieMega Diancie     Rock    king  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    king  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    king  80     160       60
# 799  721              Volcanion     Fire    king  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.loc[df['Type 1']=='Fire','Type 1']
# Out:
# 4      Fire
# 5      Fire
# 6      Fire
# 7      Fire
# 8      Fire
# 42     Fire
# 43     Fire
# 63     Fire
# 64     Fire
# 83     Fire
# 84     Fire
# 135    Fire
# 147    Fire
# 158    Fire
# 169    Fire
# 170    Fire
# 171    Fire
# 236    Fire
# 237    Fire
# 259    Fire
# 263    Fire
# 270    Fire
# 276    Fire
# 277    Fire
# 278    Fire
# 279    Fire
# 352    Fire
# 353    Fire
# 354    Fire
# 355    Fire
# 435    Fire
# 436    Fire
# 437    Fire
# 518    Fire
# 542    Fire
# 557    Fire
# 558    Fire
# 559    Fire
# 572    Fire
# 573    Fire
# 614    Fire
# 615    Fire
# 616    Fire
# 692    Fire
# 721    Fire
# 722    Fire
# 723    Fire
# 730    Fire
# 731    Fire
# 735    Fire
# 736    Fire
# 799    Fire
# Name: Type 1, dtype: object

# %%
df=pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.loc[df['total']<400]
# Out:
#        #                 Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur   Grass  Poison  45      49       49       65
# 4      4           Charmander    Fire     NaN  39      52       43       60
# 9      7             Squirtle   Water     NaN  44      48       65       50
# 13    10             Caterpie     Bug     NaN  45      30       35       20
# 14    11              Metapod     Bug     NaN  50      20       55       25
# ..   ...                  ...     ...     ...  ..     ...      ...      ...
# 781  710  PumpkabooSmall Size   Ghost   Grass  44      66       70       44
# 782  710  PumpkabooLarge Size   Ghost   Grass  54      66       70       44
# 783  710  PumpkabooSuper Size   Ghost   Grass  59      66       70       44
# 788  712             Bergmite     Ice     NaN  55      69       85       32
# 790  714               Noibat  Flying  Dragon  40      30       35       45
#
#      Sp. Def  Speed  Legendary  total
# ...

# %%
df.loc[df['total']>500,['Legendary']]='testvalue'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass    king  80      82       83
# 3      3  VenusaurMega Venusaur    Grass    king  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock    king  50     100      150
# 796  719    DiancieMega Diancie     Rock    king  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    king  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    king  80     160       60
# 799  721              Volcanion     Fire    king  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.loc[df['total'] > 500,['Type 2','Legendary']] = 'king'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass    king  80      82       83
# 3      3  VenusaurMega Venusaur    Grass    king  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock    king  50     100      150
# 796  719    DiancieMega Diancie     Rock    king  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    king  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    king  80     160       60
# 799  721              Volcanion     Fire    king  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Legendary  total
# 0         65       65     45     False    318
# ...

# %%
df.loc[df['total'] < 350,['Type 1','Legendary']]=['eww','haha']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur      eww  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass    king  80      82       83
# 3      3  VenusaurMega Venusaur    Grass    king  80     100      123
# 4      4             Charmander      eww     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock    king  50     100      150
# 796  719    DiancieMega Diancie     Rock    king  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    king  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    king  80     160       60
# 799  721              Volcanion     Fire    king  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45       haha    318
# ...

# %%
df=pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...

# %%
df.groupby('Type 1').mean()
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
df.groupby('Type 1').mean().sort_values('Defense',ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df.groupby('Type 1').mean().sort_values('Attack',ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
df.groupby('Type 1').count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df['count']=1

# %%
df['itm']='v'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total  count itm
# 0         65       65     45      False    318      1   v
# ...

# %%
df.groupby('Type 1').count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
for df in pd.read_csv('modified.csv',chunksize=500000000):
    print('chunk DF')
    print(df)
# Out:
# chunk DF
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  total
# 0         65       65     45      False    318
# ...
